# %% [markdown]
# ***Exploratory Data Analysis***
#
# Load and Combine the final API data into 1 DataFrame

# %%
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
# Additional Imports
import os, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
df_2001 = pd.read_csv("MovieData/final_tmdb_data_2001.csv.gz")
df_2001.head(2)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /tJLV3BAlHOgscVOrA99Wnb2gAef.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
#
#         id original_language  original_title  ...     revenue  runtime  \
# 0      NaN               NaN             NaN  ...         NaN      NaN
# 1  11232.0                en  Kate & Leopold  ...  76019048.0    118.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
#
#                                              tagline           title  video  \
# ...

# %%
df_2002 = pd.read_csv("MovieData/final_tmdb_data_2002.csv.gz")
df_2002.head(2)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0096056    0.0  /95U3MUDXu4xSCmVLtWgargRipDi.jpg                   NaN
#
#    budget                         genres homepage        id original_language  \
# 0     NaN                            NaN      NaN       NaN               NaN
# 1     0.0  [{'id': 18, 'name': 'Drama'}]      NaN  109809.0                en
#
#          original_title  ... revenue  runtime  \
# 0                   NaN  ...     NaN      NaN
# 1  Crime and Punishment  ...     0.0    126.0
#
#                                     spoken_languages    status tagline  \
# 0                                                NaN       NaN     NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released     NaN
#
#                   title  video  vote_average vote_count certification
# ...

# %%
df_merged = pd.concat([df_2001, df_2002], ignore_index=True, sort=False)

# %%
df_merged.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /tJLV3BAlHOgscVOrA99Wnb2gAef.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg                   NaN
# 4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3         0.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN
# 4  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
#
# ...

# %% [markdown]
# **Create Visualizations to Answer the Following Questions:**
# -

# %% [markdown]
# How many movies had at least some valid financial information (values > 0 for budget OR revenue)?
# -
# Please exclude any movies with 0's for budget AND revenue from the remaining visualizations.

# %%
df_merged = df_merged[(df_merged.budget != 0) & (df_merged.revenue != 0)]

# %%
df_merged.shape
# Out:
# (413, 26)

# %%
df_merged.head()
# Out:
#       imdb_id  adult                     backdrop_path  \
# 0           0    NaN                               NaN
# 1   tt0035423    0.0  /tJLV3BAlHOgscVOrA99Wnb2gAef.jpg
# 4   tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
# 9   tt0120681    0.0  /xo2S7gRwCvWdVqM0Swv37yA2rzw.jpg
# 10  tt0120737    0.0  /x2RS3uTcsJJ9IfjNPcgDmukoEcQ.jpg
#
#                                 belongs_to_collection      budget  \
# 0                                                 NaN         NaN
# 1                                                 NaN  48000000.0
# 4                                                 NaN  22000000.0
# 9                                                 NaN  35000000.0
# 10  {'id': 119, 'name': 'The Lord of the Rings Col...  93000000.0
#
#                                                genres  \
# 0                                                 NaN
# 1   [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# ...

# %%
df_merged.tail()
# Out:
#         imdb_id  adult                     backdrop_path  \
# 2490  tt0364385    0.0  /3ZDkl8rsoLe6g4FRV9alNH5sZOt.jpg
# 2498  tt0365960    0.0  /ahXtNFVHtFxvjphZN8QlHRVsu9W.jpg
# 2585  tt0757920    0.0  /sOkmFOVcDmH2P4GU9Mvyc4ZBC3D.jpg
# 2601  tt1039983    0.0  /7B5IQdNNyNsSwBaW9zzCT9XmAcJ.jpg
# 2622  tt1621767    0.0                               NaN
#
#                                   belongs_to_collection     budget  \
# 2490  {'id': 1972, 'name': 'Ju-on Collection', 'post...  3500000.0
# 2498                                                NaN    20000.0
# 2585                                                NaN    10000.0
# 2601                                                NaN   500000.0
# 2622                                                NaN   400000.0
#
#                                                  genres homepage       id  \
# 2490                     [{'id': 27, 'name': 'Horror'}]      NaN  11838.0
# ...

# %%
# Seaborn countplot
ax = sns.countplot(data=df_merged, x="budget")

# %% [markdown]
# How many movies are there in each of the certification categories (G/PG/PG-13/R)?
# -

# %%
# Countplot with many categories
ax = sns.countplot(data=df_merged, x="certification")

# %% [markdown]
# What is the average revenue per certification category?
# -

# %%
# Making a seaborn barplot as a starting point
ax = sns.barplot(data=df_merged, x='certification', y='revenue')

# %% [markdown]
# What is the average budget per certification category?
# -

# %%
# Making a seaborn barplot as a starting point
ax = sns.barplot(data=df_merged, x='certification', y='budget')

# %% [markdown]
# After you have joined the tmdb results into one dataframe in the EDA Notebook,
# -
#
# Save a final merged .csv.gz of all of the tmdb api da. ta
# The file name should be "tmdb_results_combined.csv.gz"he link

# %%
df_merged.to_csv("MovieData/tmdb_results_combined.csv.gz", index=False)
